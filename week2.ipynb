# %%
import pandas as pd
import numpy as np
df = pd.read_csv("home_loan.csv")
df.head(10)
pd.__version__
# Out:
# '1.4.4'

# %%
df.head(4)
df.iloc[0].tolist()
# Out:
# ['LP001015',
#  'Male',
#  'Yes',
#  '0',
#  'Graduate',
#  'No',
#  5720,
#  0,
#  110.0,
#  360.0,
#  1.0,
#  'Urban']

# %%
df.loc[0]
df.loc[0].tolist()
# Out:
# ['LP001015',
#  'Male',
#  'Yes',
#  '0',
#  'Graduate',
#  'No',
#  5720,
#  0,
#  110.0,
#  360.0,
#  1.0,
#  'Urban']

# %%
df.tail(2)
# Out:
#       Loan_ID Gender Married Dependents Education Self_Employed  \
# 365  LP002986   Male     Yes          0  Graduate            No
# 366  LP002989   Male      No          0  Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 365             5000               2393       158.0             360.0
# 366             9200                  0        98.0             180.0
#
#      Credit_History Property_Area
# 365             1.0         Rural
# 366             1.0         Rural

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 367 entries, 0 to 366
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Loan_ID            367 non-null    object
#  1   Gender             356 non-null    object
#  2   Married            367 non-null    object
#  3   Dependents         357 non-null    object
#  4   Education          367 non-null    object
#  5   Self_Employed      344 non-null    object
#  6   ApplicantIncome    367 non-null    int64
#  7   CoapplicantIncome  367 non-null    int64
#  8   LoanAmount         362 non-null    float64
#  9   Loan_Amount_Term   361 non-null    float64
#  10  Credit_History     338 non-null    float64
#  11  Property_Area      367 non-null    object
# dtypes: float64(3), int64(2), object(7)
# memory usage: 34.5+ KB

# %%
df.describe()
# Out:
#        ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# count       367.000000         367.000000  362.000000        361.000000
# mean       4805.599455        1569.577657  136.132597        342.537396
# std        4910.685399        2334.232099   61.366652         65.156643
# min           0.000000           0.000000   28.000000          6.000000
# 25%        2864.000000           0.000000  100.250000        360.000000
# 50%        3786.000000        1025.000000  125.000000        360.000000
# 75%        5060.000000        2430.500000  158.000000        360.000000
# max       72529.000000       24000.000000  550.000000        480.000000
#
#        Credit_History
# count      338.000000
# mean         0.825444
# std          0.380150
# min          0.000000
# 25%          1.000000
# 50%          1.000000
# 75%          1.000000
# max          1.000000

# %%
df.info()
new_df = df.dropna()
new_df.info()
new_df.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 367 entries, 0 to 366
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Loan_ID            367 non-null    object
#  1   Gender             356 non-null    object
#  2   Married            367 non-null    object
#  3   Dependents         357 non-null    object
#  4   Education          367 non-null    object
#  5   Self_Employed      344 non-null    object
#  6   ApplicantIncome    367 non-null    int64
#  7   CoapplicantIncome  367 non-null    int64
#  8   LoanAmount         362 non-null    float64
#  9   Loan_Amount_Term   361 non-null    float64
#  10  Credit_History     338 non-null    float64
#  11  Property_Area      367 non-null    object
# dtypes: float64(3), int64(2), object(7)
# memory usage: 34.5+ KB
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 289 entries, 0 to 366
# Data columns (total 12 columns):
# ...

# %%
df.info()
df.fillna(0, inplace=True)
df
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 367 entries, 0 to 366
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Loan_ID            367 non-null    object
#  1   Gender             367 non-null    object
#  2   Married            367 non-null    object
#  3   Dependents         367 non-null    object
#  4   Education          367 non-null    object
#  5   Self_Employed      367 non-null    object
#  6   ApplicantIncome    367 non-null    int64
#  7   CoapplicantIncome  367 non-null    int64
#  8   LoanAmount         367 non-null    float64
#  9   Loan_Amount_Term   367 non-null    float64
#  10  Credit_History     367 non-null    float64
#  11  Property_Area      367 non-null    object
# dtypes: float64(3), int64(2), object(7)
# memory usage: 34.5+ KB
#       Loan_ID Gender Married Dependents     Education Self_Employed  \
# ...

# %%
d = np.round(np.mean(df['LoanAmount']),2)
np.mean(df['LoanAmount'])
# Out:
# 136.13256130790188

# %%
df['LoanAmount'].fillna(d, inplace=True)

# %%
print(f"median {np.median(df['LoanAmount'])}")
td = df['LoanAmount'].sort_values().tolist()
print(td[df['LoanAmount'].count() //2])
# Out:
# median 126.0
# 126.0

# %%
df.median()['ApplicantIncome']
# Out:
# /tmp/ipykernel_24846/530051474.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df.median()
# ApplicantIncome      3786.0
# CoapplicantIncome    1025.0
# LoanAmount            126.0
# Loan_Amount_Term      360.0
# Credit_History          1.0
# dtype: float64

# %%
df['ApplicantIncome'].mode()
df['ApplicantIncome'].value_counts()
# Out:
# 5000    6
# 3500    6
# 3333    5
# 7500    4
# 2500    4
#        ..
# 724     1
# 1762    1
# 4243    1
# 4167    1
# 9200    1
# Name: ApplicantIncome, Length: 314, dtype: int64

# %%
# Out:
# 184
